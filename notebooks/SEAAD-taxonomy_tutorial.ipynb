# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import requests
import pathlib

# %%
version = '20231030'
download_base = '../../abc_download_root'

use_local_cache = True
manifest_path = 'releases/%s/manifest.json' % version

if not use_local_cache :
    url = 'https://allen-brain-cell-atlas.s3-us-west-2.amazonaws.com/' + manifest_path
    manifest = json.loads(requests.get(url).text)
else :
    file = os.path.join(download_base,manifest_path)
    with open(file,'rb') as f:
        manifest = json.load(f)
    
metadata = manifest['file_listing']['SEAAD-taxonomy']['metadata']

# %%
view_directory = os.path.join( download_base, 
                               manifest['directory_listing']['SEAAD-taxonomy']['directories']['metadata']['relative_path'], 
                              'views')
view_directory = pathlib.Path( view_directory )
cache_views = True
if cache_views :
    os.makedirs( view_directory, exist_ok=True )

# %%
rpath = metadata['cluster_annotation_term_set']['files']['csv']['relative_path']
file = os.path.join( download_base, rpath)
term_set = pd.read_csv(file)
term_set.set_index('label',inplace=True)
term_set
# Out:
#                                 name parent_term_set_label  term_set_order
# label
# CCN20230508_CLAS               class                   NaN               0
# CCN20230508_SUBC            subclass      CCN20230508_CLAS               1
# CCN20230508_SUPT           supertype      CCN20230508_SUBC               2
# CCN20230508_ACPS  abundancechangecps                   NaN               3

# %%
rpath = metadata['cluster_annotation_term']['files']['csv']['relative_path']
file = os.path.join( download_base, rpath)
term = pd.read_csv(file, keep_default_na=False)
term.set_index('label',inplace=True)
term.head(5)
# Out:
#                                               name  \
# label
# CCN20230508_CLAS_0001          Neuronal: GABAergic
# CCN20230508_CLAS_0002      Neuronal: Glutamatergic
# CCN20230508_CLAS_0003  Non-neuronal and Non-neural
# CCN20230508_SUBC_0001                   Lamp5 Lhx6
# CCN20230508_SUBC_0002                        Lamp5
#
#                       cluster_annotation_term_set_label  \
# label
# CCN20230508_CLAS_0001                  CCN20230508_CLAS
# CCN20230508_CLAS_0002                  CCN20230508_CLAS
# CCN20230508_CLAS_0003                  CCN20230508_CLAS
# CCN20230508_SUBC_0001                  CCN20230508_SUBC
# CCN20230508_SUBC_0002                  CCN20230508_SUBC
#
#                            parent_term_label parent_term_set_label  \
# label
# CCN20230508_CLAS_0001
# CCN20230508_CLAS_0002
# CCN20230508_CLAS_0003
# CCN20230508_SUBC_0001  CCN20230508_CLAS_0001      CCN20230508_CLAS
# CCN20230508_SUBC_0002  CCN20230508_CLAS_0001      CCN20230508_CLAS
#
#                        term_order color_hex_triplet  \
# label
# CCN20230508_CLAS_0001           1           #F05A28
# CCN20230508_CLAS_0002           2           #00ADF8
# CCN20230508_CLAS_0003           3           #808080
# CCN20230508_SUBC_0001           1           #935F50
# CCN20230508_SUBC_0002           2           #DA808C
#
#                       cluster_annotation_term_set_name     parent_term_name
# label
# CCN20230508_CLAS_0001                            class
# CCN20230508_CLAS_0002                            class
# CCN20230508_CLAS_0003                            class
# CCN20230508_SUBC_0001                         subclass  Neuronal: GABAergic
# CCN20230508_SUBC_0002                         subclass  Neuronal: GABAergic

# %%
term_count = term[['cluster_annotation_term_set_name','name']].groupby('cluster_annotation_term_set_name').count()
term_count.columns = ['count']
term_count
# Out:
#                                   count
# cluster_annotation_term_set_name
# abundancechangecps                    3
# class                                 3
# subclass                             24
# supertype                           139

# %%
rpath = metadata['cluster_to_cluster_annotation_membership']['files']['csv']['relative_path']
file = os.path.join( download_base, rpath)
membership = pd.read_csv(file, keep_default_na=False)
membership
# Out:
#            cluster_alias cluster_annotation_term_name  \
# 0           Lamp5_Lhx6_1          Neuronal: GABAergic
# 1                Lamp5_1          Neuronal: GABAergic
# 2                Lamp5_2          Neuronal: GABAergic
# 3                Lamp5_3          Neuronal: GABAergic
# 4                Lamp5_4          Neuronal: GABAergic
# ..                   ...                          ...
# 551          Micro-PVM_2                    unchanged
# 552  Micro-PVM_2_3-SEAAD                    unchanged
# 553    Micro-PVM_3-SEAAD                     increase
# 554    Micro-PVM_4-SEAAD                    unchanged
# 555           Lymphocyte                    unchanged
#
#     cluster_annotation_term_label cluster_annotation_term_set_label  \
# 0           CCN20230508_CLAS_0001                  CCN20230508_CLAS
# 1           CCN20230508_CLAS_0001                  CCN20230508_CLAS
# 2           CCN20230508_CLAS_0001                  CCN20230508_CLAS
# 3           CCN20230508_CLAS_0001                  CCN20230508_CLAS
# 4           CCN20230508_CLAS_0001                  CCN20230508_CLAS
# ..                            ...                               ...
# 551         CCN20230508_ACPS_0001                  CCN20230508_ACPS
# 552         CCN20230508_ACPS_0001                  CCN20230508_ACPS
# 553         CCN20230508_ACPS_0002                  CCN20230508_ACPS
# 554         CCN20230508_ACPS_0001                  CCN20230508_ACPS
# 555         CCN20230508_ACPS_0001                  CCN20230508_ACPS
#
#     cluster_annotation_term_set_name color_hex_triplet
# 0                              class           #F05A28
# 1                              class           #F05A28
# 2                              class           #F05A28
# 3                              class           #F05A28
# 4                              class           #F05A28
# ..                               ...               ...
# 551               abundancechangecps           #F7F7F7
# 552               abundancechangecps           #F7F7F7
# 553               abundancechangecps           #B2182B
# 554               abundancechangecps           #F7F7F7
# 555               abundancechangecps           #F7F7F7
#
# [556 rows x 6 columns]

# %%
pivot = membership.groupby(['cluster_alias','cluster_annotation_term_set_name'])['cluster_annotation_term_name'].first().unstack()
pivot.drop_duplicates(inplace=True)
pivot
# Out:
# cluster_annotation_term_set_name abundancechangecps  \
# cluster_alias
# Astro_1                                   unchanged
# Astro_2                                    increase
# Astro_3                                   unchanged
# Astro_4                                   unchanged
# Astro_5                                   unchanged
# ...                                             ...
# Vip_23                                    unchanged
# Vip_4                                     unchanged
# Vip_5                                     unchanged
# Vip_6                                     unchanged
# Vip_9                                     unchanged
#
# cluster_annotation_term_set_name                        class   subclass  \
# cluster_alias
# Astro_1                           Non-neuronal and Non-neural  Astrocyte
# Astro_2                           Non-neuronal and Non-neural  Astrocyte
# Astro_3                           Non-neuronal and Non-neural  Astrocyte
# Astro_4                           Non-neuronal and Non-neural  Astrocyte
# Astro_5                           Non-neuronal and Non-neural  Astrocyte
# ...                                                       ...        ...
# Vip_23                                    Neuronal: GABAergic        Vip
# Vip_4                                     Neuronal: GABAergic        Vip
# Vip_5                                     Neuronal: GABAergic        Vip
# Vip_6                                     Neuronal: GABAergic        Vip
# Vip_9                                     Neuronal: GABAergic        Vip
#
# cluster_annotation_term_set_name supertype
# cluster_alias
# Astro_1                            Astro_1
# Astro_2                            Astro_2
# Astro_3                            Astro_3
# Astro_4                            Astro_4
# Astro_5                            Astro_5
# ...                                    ...
# Vip_23                              Vip_23
# Vip_4                                Vip_4
# Vip_5                                Vip_5
# Vip_6                                Vip_6
# Vip_9                                Vip_9
#
# [139 rows x 4 columns]

# %%
color = membership.groupby(['cluster_alias','cluster_annotation_term_set_name'])['color_hex_triplet'].first().unstack().fillna('#f9f9f9')
color.drop_duplicates(inplace=True)
color.columns = ['%s_color' % x for x in color.columns]
color
# Out:
#               abundancechangecps_color class_color subclass_color  \
# cluster_alias
# Astro_1                        #F7F7F7     #808080        #665C47
# Astro_2                        #B2182B     #808080        #665C47
# Astro_3                        #F7F7F7     #808080        #665C47
# Astro_4                        #F7F7F7     #808080        #665C47
# Astro_5                        #F7F7F7     #808080        #665C47
# ...                                ...         ...            ...
# Vip_23                         #F7F7F7     #F05A28        #A45FBF
# Vip_4                          #F7F7F7     #F05A28        #A45FBF
# Vip_5                          #F7F7F7     #F05A28        #A45FBF
# Vip_6                          #F7F7F7     #F05A28        #A45FBF
# Vip_9                          #F7F7F7     #F05A28        #A45FBF
#
#               supertype_color
# cluster_alias
# Astro_1               #D1C9BA
# Astro_2               #AAA395
# Astro_3               #847D71
# Astro_4               #5E574C
# Astro_5               #383228
# ...                       ...
# Vip_23                #492C56
# Vip_4                 #CC9EE1
# Vip_5                 #C598D9
# Vip_6                 #BE92D2
# Vip_9                 #A980BC
#
# [139 rows x 4 columns]

# %%
if cache_views :
    
    file = os.path.join( view_directory, 'cluster_to_cluster_annotation_membership_pivoted.csv')
    pivot.to_csv( file )
    
    file = os.path.join( view_directory, 'cluster_to_cluster_annotation_membership_color.csv')
    color.to_csv( file )
