# %%
import os
import pandas as pd
from pathlib import Path
import numpy as np
import anndata
import time
import matplotlib.pyplot as plt
import json

from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache

pd.set_option('display.max_columns', 500)

# %%
version = '20250630'
download_base = Path('../../../data/abc_atlas')
abc_cache = AbcProjectCache.from_cache_dir(
    download_base,
    s3_bucket='allen-brain-cell-atlas-staging',
    auth_required=True
)
abc_cache.load_manifest(f'releases/{version}/manifest.json')

# %% [markdown]
# Read in the two DataFrames from the aging dataset we'll need to create an equivalent cluster annotation terms and term set like the WMB and WHB taxonomies.

# %%
abc_cache.list_metadata_files('HMBA-BG-taxonomy-CCN20250428')
# Out:
# ['abbreviation_term',
#  'cell_2d_embedding_coordinates',
#  'cell_to_cluster_membership',
#  'cluster',
#  'cluster_annotation_term',
#  'cluster_annotation_term_set',
#  'cluster_annotation_to_abbreviation_map',
#  'cluster_to_cluster_annotation_membership']

# %%
term = abc_cache.get_metadata_dataframe(
    'HMBA-BG-taxonomy-CCN20250428',
    'cluster_annotation_term'
)
term
# Out:
#                       label                  name  \
# 0     CS20250428_NEIGH_0001             Nonneuron
# 1     CS20250428_NEIGH_0000        Glut Sero Dopa
# 2     CS20250428_NEIGH_0002       Subpallium GABA
# 3     CS20250428_NEIGH_0003  Subpallium GABA-Glut
# 4     CS20250428_CLASS_0000            Astro-Epen
# ...                     ...                   ...
# 1543  CS20250428_CLUST_0671           Macaque-490
# 1544  CS20250428_CLUST_0672           Macaque-491
# 1545  CS20250428_CLUST_0673           Macaque-492
# 1546  CS20250428_CLUST_1771          Marmoset-859
# 1547  CS20250428_CLUST_1773          Marmoset-861
#
#      cluster_annotation_term_set_label cluster_annotation_term_set_name  \
# 0                  CCN20250428_LEVEL_0                     Neighborhood
# 1                  CCN20250428_LEVEL_0                     Neighborhood
# 2                  CCN20250428_LEVEL_0                     Neighborhood
# 3                  CCN20250428_LEVEL_0                     Neighborhood
# 4                  CCN20250428_LEVEL_1                            Class
# ...                                ...                              ...
# 1543               CCN20250428_LEVEL_4                          Cluster
# 1544               CCN20250428_LEVEL_4                          Cluster
# 1545               CCN20250428_LEVEL_4                          Cluster
# 1546               CCN20250428_LEVEL_4                          Cluster
# 1547               CCN20250428_LEVEL_4                          Cluster
#
#      color_hex_triplet  term_order  term_set_order      parent_term_label  \
# 0              #a8afa5           1               0                    NaN
# 1              #91f4bb           2               0                    NaN
# 2              #19613b           3               0                    NaN
# 3              #7e1d19           4               0                    NaN
# 4              #401e66           1               1  CS20250428_NEIGH_0001
# ...                ...         ...             ...                    ...
# 1543           #a2b102        1430               4  CS20250428_GROUP_0016
# 1544           #e5de92        1431               4  CS20250428_GROUP_0016
# 1545           #e1d71e        1432               4  CS20250428_GROUP_0016
# 1546           #1e3a5b        1433               4  CS20250428_GROUP_0016
# 1547           #45f6a7        1434               4  CS20250428_GROUP_0016
#
#      parent_term_name parent_term_set_label
# 0                 NaN                   NaN
# 1                 NaN                   NaN
# 2                 NaN                   NaN
# 3                 NaN                   NaN
# 4           Nonneuron   CCN20250428_LEVEL_0
# ...               ...                   ...
# 1543        GPi Shell   CCN20250428_LEVEL_3
# 1544        GPi Shell   CCN20250428_LEVEL_3
# 1545        GPi Shell   CCN20250428_LEVEL_3
# 1546        GPi Shell   CCN20250428_LEVEL_3
# 1547        GPi Shell   CCN20250428_LEVEL_3
#
# [1548 rows x 10 columns]

# %%
term_sets = abc_cache.get_metadata_dataframe(directory='HMBA-BG-taxonomy-CCN20250428', file_name='cluster_annotation_term_set').set_index('label')
term_sets
# Out:
#                              name   description  order
# label
# CCN20250428_LEVEL_0  Neighborhood  Neighborhood      0
# CCN20250428_LEVEL_1         Class         Class      1
# CCN20250428_LEVEL_2      Subclass      Subclass      2
# CCN20250428_LEVEL_3         Group         Group      3
# CCN20250428_LEVEL_4       Cluster       Cluster      4

# %%
filtered = term[pd.notna(term['parent_term_label'])]
first_child = filtered.groupby('parent_term_label')[['label','name','term_order','cluster_annotation_term_set_name']].first()
first_child
# Out:
#                                        label                  name  \
# parent_term_label
# CS20250428_CLASS_0000  CS20250428_SUBCL_0000             Astrocyte
# CS20250428_CLASS_0001  CS20250428_SUBCL_0002  CN LAMP5-CXCL14 GABA
# CS20250428_CLASS_0002  CS20250428_SUBCL_0014          CN GABA-Glut
# CS20250428_CLASS_0003  CS20250428_SUBCL_0006         CN MEIS2 GABA
# CS20250428_CLASS_0005  CS20250428_SUBCL_0003    CN LAMP5-LHX6 GABA
# ...                                      ...                   ...
# CS20250428_SUBCL_0033  CS20250428_GROUP_0043    STR SST-CHODL GABA
# CS20250428_SUBCL_0035  CS20250428_GROUP_0062                  VLMC
# CS20250428_SUBCL_0036  CS20250428_GROUP_0068         OB FRMD7 GABA
# CS20250428_SUBCL_0037  CS20250428_GROUP_0063           ZI-HTH GABA
# CS20250428_SUBCL_0038  CS20250428_GROUP_0022              Monocyte
#
#                        term_order cluster_annotation_term_set_name
# parent_term_label
# CS20250428_CLASS_0000           1                         Subclass
# CS20250428_CLASS_0001          23                         Subclass
# CS20250428_CLASS_0002          36                         Subclass
# CS20250428_CLASS_0003          30                         Subclass
# CS20250428_CLASS_0005          17                         Subclass
# ...                           ...                              ...
# CS20250428_SUBCL_0033          29                            Group
# CS20250428_SUBCL_0035          17                            Group
# CS20250428_SUBCL_0036          60                            Group
# CS20250428_SUBCL_0037          46                            Group
# CS20250428_SUBCL_0038           8                            Group
#
# [113 rows x 4 columns]

# %%
term.set_index('label',inplace=True)
term.loc[first_child.index,'first_child_label'] = first_child['label']
term.loc[first_child.index,'first_child_term_set_name'] = first_child['cluster_annotation_term_set_name']
term.reset_index(inplace=True)

# %%
term[pd.notna(term['first_child_label'])]
# Out:
#                      label                  name  \
# 0    CS20250428_NEIGH_0001             Nonneuron
# 1    CS20250428_NEIGH_0000        Glut Sero Dopa
# 2    CS20250428_NEIGH_0002       Subpallium GABA
# 3    CS20250428_NEIGH_0003  Subpallium GABA-Glut
# 4    CS20250428_CLASS_0000            Astro-Epen
# ..                     ...                   ...
# 108  CS20250428_GROUP_0051   STR D1D2 Hybrid MSN
# 109  CS20250428_GROUP_0024             OT D1 ICj
# 110  CS20250428_GROUP_0068         OB FRMD7 GABA
# 111  CS20250428_GROUP_0067          OB Dopa-GABA
# 112  CS20250428_GROUP_0016             GPi Shell
#
#     cluster_annotation_term_set_label cluster_annotation_term_set_name  \
# 0                 CCN20250428_LEVEL_0                     Neighborhood
# 1                 CCN20250428_LEVEL_0                     Neighborhood
# 2                 CCN20250428_LEVEL_0                     Neighborhood
# 3                 CCN20250428_LEVEL_0                     Neighborhood
# 4                 CCN20250428_LEVEL_1                            Class
# ..                                ...                              ...
# 108               CCN20250428_LEVEL_3                            Group
# 109               CCN20250428_LEVEL_3                            Group
# 110               CCN20250428_LEVEL_3                            Group
# 111               CCN20250428_LEVEL_3                            Group
# 112               CCN20250428_LEVEL_3                            Group
#
#     color_hex_triplet  term_order  term_set_order      parent_term_label  \
# 0             #a8afa5           1               0                    NaN
# 1             #91f4bb           2               0                    NaN
# 2             #19613b           3               0                    NaN
# 3             #7e1d19           4               0                    NaN
# 4             #401e66           1               1  CS20250428_NEIGH_0001
# ..                ...         ...             ...                    ...
# 108           #9467bd          58               3  CS20250428_SUBCL_0030
# 109           #ff7f0e          59               3  CS20250428_SUBCL_0021
# 110           #cd0753          60               3  CS20250428_SUBCL_0036
# 111           #902f6b          61               3  CS20250428_SUBCL_0036
# 112           #642265          62               3  CS20250428_SUBCL_0014
#
#      parent_term_name parent_term_set_label      first_child_label  \
# 0                 NaN                   NaN  CS20250428_CLASS_0000
# 1                 NaN                   NaN  CS20250428_CLASS_0007
# 2                 NaN                   NaN  CS20250428_CLASS_0005
# 3                 NaN                   NaN  CS20250428_CLASS_0002
# 4           Nonneuron   CCN20250428_LEVEL_0  CS20250428_SUBCL_0000
# ..                ...                   ...                    ...
# 108    STR Hybrid MSN   CCN20250428_LEVEL_2  CS20250428_CLUST_0457
# 109  OT Granular GABA   CCN20250428_LEVEL_2  CS20250428_CLUST_0336
# 110    ACx MEIS2 GABA   CCN20250428_LEVEL_2  CS20250428_CLUST_0025
# 111    ACx MEIS2 GABA   CCN20250428_LEVEL_2  CS20250428_CLUST_0024
# 112      CN GABA-Glut   CCN20250428_LEVEL_2  CS20250428_CLUST_0398
#
#     first_child_term_set_name
# 0                       Class
# 1                       Class
# 2                       Class
# 3                       Class
# 4                    Subclass
# ..                        ...
# 108                   Cluster
# 109                   Cluster
# 110                   Cluster
# 111                   Cluster
# 112                   Cluster
#
# [113 rows x 12 columns]

# %%
membership = abc_cache.get_metadata_dataframe(directory='HMBA-BG-taxonomy-CCN20250428', file_name='cluster_to_cluster_annotation_membership')
pivot = membership.groupby(['cluster_alias', 'cluster_annotation_term_set_name'])['cluster_annotation_term_name'].first().unstack()
pivot = pivot[term_sets['name']] # order columns
pivot.fillna('Other', inplace=True)
pivot.sort_values(['Neighborhood', 'Class', 'Subclass', 'Group', 'Cluster'], inplace=True)
cols = pivot.columns.to_list()
pivot.columns = cols
pivot
# Out:
#                        Neighborhood         Class      Subclass  \
# cluster_alias
# Human-128            Glut Sero Dopa      F M Glut        F Glut
# Human-129            Glut Sero Dopa      F M Glut        F Glut
# Human-130            Glut Sero Dopa      F M Glut        F Glut
# Human-423            Glut Sero Dopa      F M Glut        F Glut
# Human-426            Glut Sero Dopa      F M Glut        F Glut
# ...                             ...           ...           ...
# Macaque-490    Subpallium GABA-Glut  CN GABA-Glut  CN GABA-Glut
# Macaque-491    Subpallium GABA-Glut  CN GABA-Glut  CN GABA-Glut
# Macaque-492    Subpallium GABA-Glut  CN GABA-Glut  CN GABA-Glut
# Marmoset-859   Subpallium GABA-Glut  CN GABA-Glut  CN GABA-Glut
# Marmoset-861   Subpallium GABA-Glut  CN GABA-Glut  CN GABA-Glut
#
#                        Group       Cluster
# cluster_alias
# Human-128      BF SKOR1 Glut     Human-128
# Human-129      BF SKOR1 Glut     Human-129
# Human-130      BF SKOR1 Glut     Human-130
# Human-423      BF SKOR1 Glut     Human-423
# Human-426      BF SKOR1 Glut     Human-426
# ...                      ...           ...
# Macaque-490        GPi Shell   Macaque-490
# Macaque-491        GPi Shell   Macaque-491
# Macaque-492        GPi Shell   Macaque-492
# Marmoset-859       GPi Shell  Marmoset-859
# Marmoset-861       GPi Shell  Marmoset-861
#
# [1435 rows x 5 columns]

# %%
lookup = {}
for tag in term_sets['name'] :
    #print(tag)
    pred = (term['cluster_annotation_term_set_name'] == tag)
    filtered = term[pred].copy()
    filtered.set_index('name', inplace=True)
    lookup[tag] = filtered

# %% [markdown]
# Helper functions to lookup an term attribut and format a cell in the html table

# %%
def get_value(c, n, v) :
    return lookup[c].loc[n][v]

def format_cell (df,c,add_id=False,add_plus=False,add_minus=False) :

    divs = pd.DataFrame(index=df.index)
    
    pattern = '<div class="circle" style="background-color:%s"></div>'
    divs['circle'] = [pattern % get_value(c,x,'color_hex_triplet') for x in df[c]]
    
    pattern = '<div class="celltext">%s</div>'
    divs['name'] = [pattern % x for x in df[c]]
   
    divs['id'] = ''
    if add_id :
        pattern = '<div id="%s"></div>'
        divs['id'] = [pattern % get_value(c,x,'label') for x in df[c]]
        
    divs['plus'] = ''
    if add_plus :
        pattern = '<div class="celltext"><a href="%s.html#%s">[+]</a></div>'
        divs['plus'] = [pattern % (get_value(c,x,'first_child_term_set_name'),
                                   get_value(c,x,'first_child_label')) for x in df[c]]
        
    divs['minus'] = ''
    if add_minus :
        pattern = '<div class="celltext"><a href="%s.html#%s">[-]</a></div>'
        divs['minus'] = [pattern % (get_value(c,x,'cluster_annotation_term_set_name'),
                                    get_value(c,x,'label')) for x in df[c]]
    
    cols = ['id','circle','name','plus','minus']
    output = divs[cols].apply(lambda row: ''.join(row.values.astype(str)), axis=1)
    return output

# %% [markdown]
# Helper function to create html document

# %%
def create_html(df, ts, file, title):
    
    # apply formatter to each term set
    df_formatted = df.copy()
    
    for tag in term_sets['name'] :
        if tag in df_formatted.columns :
            
            add_id = False
            if tag == ts :
                add_id = True
                
            add_plus = False
            if tag == ts and tag not in ('Cluster') :
                add_plus = True
                
            add_minus = False
            if tag != ts and tag not in ('Cluster') :
                add_minus = True
                
            df_formatted[tag] = format_cell(df,tag,add_id,add_plus,add_minus)
            
            
    output = df_formatted.to_html(index=False, na_rep='',
                        render_links=True,escape=False,
                        classes="mystyle")

    html_string = '''
    <html>
    <head><title>%s</title></head>
    <link rel="stylesheet" type="text/css" href="../../simple_style.css"/>
    <body>
    {table}
    </body>
    </html>.
    ''' % title

    # OUTPUT AN HTML FILE
    with open(file, 'w') as f:
        f.write(html_string.format(table=output))

# %%
# Write the data to the _static directory of the abc_atlas_access so that links work properly in the jupyter-book/sphinx page.
output_directory = os.path.join('../../_static', 'HMBA-BG-taxonomy-CCN20250428', version)
os.makedirs(output_directory, exist_ok=True)

# %%
df_supertype = pivot[['Neighborhood']].copy()
df_supertype.drop_duplicates(inplace=True)

file = os.path.join(output_directory, 'Neighborhood.html')
title = 'HMBA-BG-taxonomy-CCN20250428: cell type Neighborhood'
create_html(df_supertype, 'Neighborhood', file, title)
print(len(df_supertype))
# Out:
# 4

# %%
df_supertype = pivot[['Neighborhood', 'Class']].copy()
df_supertype.drop_duplicates(inplace=True)

file = os.path.join(output_directory, 'Class.html')
title = 'HMBA-BG-taxonomy-CCN20250428: cell type Class'
create_html(df_supertype, 'Class', file, title)
print(len(df_supertype))
# Out:
# 12

# %%
df_supertype = pivot[['Neighborhood', 'Class', 'Subclass']].copy()
df_supertype.drop_duplicates(inplace=True)

file = os.path.join(output_directory,'Subclass.html')
title = 'HMBA-BG-taxonomy-CCN20250428: cell type Subclass'
create_html(df_supertype, 'Subclass', file, title)
print(len(df_supertype))
# Out:
# 36

# %%
df_supertype = pivot[['Neighborhood', 'Class', 'Subclass', 'Group']].copy()
df_supertype.drop_duplicates(inplace=True)

file = os.path.join(output_directory,'Group.html')
title = 'HMBA-BG-taxonomy-CCN20250428: cell type Group'
create_html(df_supertype, 'Group', file, title)
print(len(df_supertype))
# Out:
# 61

# %%
df_supertype = pivot[['Neighborhood', 'Class', 'Subclass', 'Group', 'Cluster']].copy()
df_supertype.drop_duplicates(inplace=True)

file = os.path.join(output_directory,'Cluster.html')
title = 'HMBA-BG-taxonomy-CCN20250428: cell type Cluster'
create_html(df_supertype, 'Cluster', file, title)
print(len(df_supertype))
# Out:
# 1435
