# %%
import os
import pandas as pd
from pathlib import Path
import numpy as np
import anndata
import time
import matplotlib.pyplot as plt
import json

from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache

pd.set_option('display.max_columns', 500)

# %%
version = '20250331'
download_base = Path('../../../data/abc_atlas')
abc_cache = AbcProjectCache.from_s3_cache(download_base)
abc_cache.list_manifest_file_names.append(f'releases/{version}/manifest.json')
abc_cache.load_manifest(f'releases/{version}/manifest.json')
# Out:
# /allen/scratch/aibstemp/chris.morrison/src/abc_atlas_access/src/abc_atlas_access/abc_atlas_cache/cloud_cache.py:616: UserWarning: The manifest version recorded as last used for this cache -- releases/20250331/manifest.json-- is not a valid manifest for this dataset. Loading latest version -- releases/20250131/manifest.json -- instead.
#   warnings.warn(msg, UserWarning)
# /allen/scratch/aibstemp/chris.morrison/src/abc_atlas_access/src/abc_atlas_access/abc_atlas_cache/cloud_cache.py:648: OutdatedManifestWarning: You are loading
# releases/20250131/manifest.json
# which is newer than the most recent manifest file you have previously been working with
# releases/20250331/manifest.json
# It is possible that some data files have changed between these two data releases, which will force you to re-download those data files (currently downloaded files will not be overwritten). To continue using releases/20250331/manifest.json, run
# type.load_manifest('releases/20250331/manifest.json')
#   warnings.warn(msg, OutdatedManifestWarning)

# %% [markdown]
# Read in the two DataFrames from the aging dataset we'll need to create an equivalent cluster annotation terms and term set like the WMB and WHB taxonomies.

# %%
abc_cache.list_metadata_files('SEAAD-taxonomy')
# Out:
# ['cluster_annotation_term',
#  'cluster_annotation_term_set',
#  'cluster_to_cluster_annotation_membership']

# %%
term = abc_cache.get_metadata_dataframe(
    'SEAAD-taxonomy',
    'cluster_annotation_term'
)
term
# Out:
#                             name cluster_annotation_term_set_label  \
# 0            Neuronal: GABAergic                  CCN20230508_CLAS
# 1        Neuronal: Glutamatergic                  CCN20230508_CLAS
# 2    Non-neuronal and Non-neural                  CCN20230508_CLAS
# 3                     Lamp5 Lhx6                  CCN20230508_SUBC
# 4                          Lamp5                  CCN20230508_SUBC
# ..                           ...                               ...
# 164            Micro-PVM_4-SEAAD                  CCN20230508_SUPT
# 165                   Lymphocyte                  CCN20230508_SUPT
# 166                    unchanged                  CCN20230508_ACPS
# 167                     decrease                  CCN20230508_ACPS
# 168                     increase                  CCN20230508_ACPS
#
#         parent_term_label parent_term_set_label  term_order color_hex_triplet  \
# 0                     NaN                   NaN           1           #F05A28
# 1                     NaN                   NaN           2           #00ADF8
# 2                     NaN                   NaN           3           #808080
# 3    CS20230508_CLAS_0001      CCN20230508_CLAS           1           #935F50
# 4    CS20230508_CLAS_0001      CCN20230508_CLAS           2           #DA808C
# ..                    ...                   ...         ...               ...
# 164  CS20230508_SUBC_0024      CCN20230508_SUBC         138           #ABC6AD
# 165  CS20230508_SUBC_0024      CCN20230508_SUBC         139           #4EAF59
# 166                   NaN                   NaN           1           #F7F7F7
# 167                   NaN                   NaN           0           #2166AC
# 168                   NaN                   NaN           2           #B2182B
#
#     cluster_annotation_term_set_name                 label  \
# 0                              class  CS20230508_CLAS_0001
# 1                              class  CS20230508_CLAS_0002
# 2                              class  CS20230508_CLAS_0003
# 3                           subclass  CS20230508_SUBC_0001
# 4                           subclass  CS20230508_SUBC_0002
# ..                               ...                   ...
# 164                        supertype  CS20230508_SUPT_0138
# 165                        supertype  CS20230508_SUPT_0139
# 166               abundancechangecps  CS20230508_ACPS_0001
# 167               abundancechangecps  CS20230508_ACPS_0000
# 168               abundancechangecps  CS20230508_ACPS_0002
#
#         parent_term_name
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3    Neuronal: GABAergic
# 4    Neuronal: GABAergic
# ..                   ...
# 164        Microglia-PVM
# 165        Microglia-PVM
# 166                  NaN
# 167                  NaN
# 168                  NaN
#
# [169 rows x 9 columns]

# %%
term_sets = abc_cache.get_metadata_dataframe(directory='SEAAD-taxonomy', file_name='cluster_annotation_term_set').set_index('label')
term_sets
# Out:
#                                 name parent_term_set_label  term_set_order
# label
# CCN20230508_CLAS               class                   NaN               0
# CCN20230508_SUBC            subclass      CCN20230508_CLAS               1
# CCN20230508_SUPT           supertype      CCN20230508_SUBC               2
# CCN20230508_ACPS  abundancechangecps                   NaN               3

# %%
filtered = term[pd.notna(term['parent_term_label'])]
first_child = filtered.groupby('parent_term_label')[['label','name','term_order','cluster_annotation_term_set_name']].first()
first_child
# Out:
#                                      label          name  term_order  \
# parent_term_label
# CS20230508_CLAS_0001  CS20230508_SUBC_0001    Lamp5 Lhx6           1
# CS20230508_CLAS_0002  CS20230508_SUBC_0010       L2/3 IT          10
# CS20230508_CLAS_0003  CS20230508_SUBC_0019     Astrocyte          19
# CS20230508_SUBC_0001  CS20230508_SUPT_0001  Lamp5_Lhx6_1           1
# CS20230508_SUBC_0002  CS20230508_SUPT_0002       Lamp5_1           2
# CS20230508_SUBC_0003  CS20230508_SUPT_0008        Pax6_1           8
# CS20230508_SUBC_0004  CS20230508_SUPT_0012        Sncg_3          12
# CS20230508_SUBC_0005  CS20230508_SUPT_0019        Vip_14          19
# CS20230508_SUBC_0006  CS20230508_SUPT_0035   Sst Chodl_1          35
# CS20230508_SUBC_0007  CS20230508_SUPT_0036         Sst_1          36
# CS20230508_SUBC_0008  CS20230508_SUPT_0053       Pvalb_6          53
# CS20230508_SUBC_0009  CS20230508_SUPT_0066  Chandelier_1          66
# CS20230508_SUBC_0010  CS20230508_SUPT_0068     L2/3 IT_1          68
# CS20230508_SUBC_0011  CS20230508_SUPT_0079       L4 IT_2          79
# CS20230508_SUBC_0012  CS20230508_SUPT_0082       L5 IT_1          82
# CS20230508_SUBC_0013  CS20230508_SUPT_0077       L6 IT_1          77
# CS20230508_SUBC_0014  CS20230508_SUPT_0102  L6 IT Car3_1         102
# CS20230508_SUBC_0015  CS20230508_SUPT_0090       L5 ET_1          90
# CS20230508_SUBC_0016  CS20230508_SUPT_0092       L6 CT_1          92
# CS20230508_SUBC_0017  CS20230508_SUPT_0096         L6b_1          96
# CS20230508_SUBC_0018  CS20230508_SUPT_0105     L5/6 NP_1         105
# CS20230508_SUBC_0019  CS20230508_SUPT_0110       Astro_1         110
# CS20230508_SUBC_0020  CS20230508_SUPT_0116         OPC_1         116
# CS20230508_SUBC_0021  CS20230508_SUPT_0120       Oligo_1         120
# CS20230508_SUBC_0022  CS20230508_SUPT_0125        Endo_1         125
# CS20230508_SUBC_0023  CS20230508_SUPT_0128        VLMC_1         128
# CS20230508_SUBC_0024  CS20230508_SUPT_0132      Monocyte         132
#
#                      cluster_annotation_term_set_name
# parent_term_label
# CS20230508_CLAS_0001                         subclass
# CS20230508_CLAS_0002                         subclass
# CS20230508_CLAS_0003                         subclass
# CS20230508_SUBC_0001                        supertype
# CS20230508_SUBC_0002                        supertype
# CS20230508_SUBC_0003                        supertype
# CS20230508_SUBC_0004                        supertype
# CS20230508_SUBC_0005                        supertype
# CS20230508_SUBC_0006                        supertype
# CS20230508_SUBC_0007                        supertype
# CS20230508_SUBC_0008                        supertype
# CS20230508_SUBC_0009                        supertype
# CS20230508_SUBC_0010                        supertype
# CS20230508_SUBC_0011                        supertype
# CS20230508_SUBC_0012                        supertype
# CS20230508_SUBC_0013                        supertype
# CS20230508_SUBC_0014                        supertype
# CS20230508_SUBC_0015                        supertype
# CS20230508_SUBC_0016                        supertype
# CS20230508_SUBC_0017                        supertype
# CS20230508_SUBC_0018                        supertype
# CS20230508_SUBC_0019                        supertype
# CS20230508_SUBC_0020                        supertype
# CS20230508_SUBC_0021                        supertype
# CS20230508_SUBC_0022                        supertype
# CS20230508_SUBC_0023                        supertype
# CS20230508_SUBC_0024                        supertype

# %%
term.set_index('label',inplace=True)
term.loc[first_child.index,'first_child_label'] = first_child['label']
term.loc[first_child.index,'first_child_term_set_name'] = first_child['cluster_annotation_term_set_name']
term.reset_index(inplace=True)

# %%
term[pd.notna(term['first_child_label'])]
# Out:
#                    label  index                         name  \
# 0   CS20230508_CLAS_0001      0          Neuronal: GABAergic
# 1   CS20230508_CLAS_0002      1      Neuronal: Glutamatergic
# 2   CS20230508_CLAS_0003      2  Non-neuronal and Non-neural
# 3   CS20230508_SUBC_0001      3                   Lamp5 Lhx6
# 4   CS20230508_SUBC_0002      4                        Lamp5
# 5   CS20230508_SUBC_0003      5                         Pax6
# 6   CS20230508_SUBC_0004      6                         Sncg
# 7   CS20230508_SUBC_0005      7                          Vip
# 8   CS20230508_SUBC_0006      8                    Sst Chodl
# 9   CS20230508_SUBC_0007      9                          Sst
# 10  CS20230508_SUBC_0008     10                        Pvalb
# 11  CS20230508_SUBC_0009     11                   Chandelier
# 12  CS20230508_SUBC_0010     12                      L2/3 IT
# 13  CS20230508_SUBC_0013     13                        L6 IT
# 14  CS20230508_SUBC_0011     14                        L4 IT
# 15  CS20230508_SUBC_0012     15                        L5 IT
# 16  CS20230508_SUBC_0015     16                        L5 ET
# 17  CS20230508_SUBC_0016     17                        L6 CT
# 18  CS20230508_SUBC_0017     18                          L6b
# 19  CS20230508_SUBC_0014     19                   L6 IT Car3
# 20  CS20230508_SUBC_0018     20                      L5/6 NP
# 21  CS20230508_SUBC_0019     21                    Astrocyte
# 22  CS20230508_SUBC_0020     22                          OPC
# 23  CS20230508_SUBC_0021     23              Oligodendrocyte
# 24  CS20230508_SUBC_0022     24                  Endothelial
# 25  CS20230508_SUBC_0023     25                         VLMC
# 26  CS20230508_SUBC_0024     26                Microglia-PVM
#
#    cluster_annotation_term_set_label     parent_term_label  \
# 0                   CCN20230508_CLAS                   NaN
# 1                   CCN20230508_CLAS                   NaN
# 2                   CCN20230508_CLAS                   NaN
# 3                   CCN20230508_SUBC  CS20230508_CLAS_0001
# 4                   CCN20230508_SUBC  CS20230508_CLAS_0001
# 5                   CCN20230508_SUBC  CS20230508_CLAS_0001
# 6                   CCN20230508_SUBC  CS20230508_CLAS_0001
# 7                   CCN20230508_SUBC  CS20230508_CLAS_0001
# 8                   CCN20230508_SUBC  CS20230508_CLAS_0001
# 9                   CCN20230508_SUBC  CS20230508_CLAS_0001
# 10                  CCN20230508_SUBC  CS20230508_CLAS_0001
# 11                  CCN20230508_SUBC  CS20230508_CLAS_0001
# 12                  CCN20230508_SUBC  CS20230508_CLAS_0002
# 13                  CCN20230508_SUBC  CS20230508_CLAS_0002
# 14                  CCN20230508_SUBC  CS20230508_CLAS_0002
# 15                  CCN20230508_SUBC  CS20230508_CLAS_0002
# 16                  CCN20230508_SUBC  CS20230508_CLAS_0002
# 17                  CCN20230508_SUBC  CS20230508_CLAS_0002
# 18                  CCN20230508_SUBC  CS20230508_CLAS_0002
# 19                  CCN20230508_SUBC  CS20230508_CLAS_0002
# 20                  CCN20230508_SUBC  CS20230508_CLAS_0002
# 21                  CCN20230508_SUBC  CS20230508_CLAS_0003
# 22                  CCN20230508_SUBC  CS20230508_CLAS_0003
# 23                  CCN20230508_SUBC  CS20230508_CLAS_0003
# 24                  CCN20230508_SUBC  CS20230508_CLAS_0003
# 25                  CCN20230508_SUBC  CS20230508_CLAS_0003
# 26                  CCN20230508_SUBC  CS20230508_CLAS_0003
#
#    parent_term_set_label  term_order color_hex_triplet  \
# 0                    NaN           1           #F05A28
# 1                    NaN           2           #00ADF8
# 2                    NaN           3           #808080
# 3       CCN20230508_CLAS           1           #935F50
# 4       CCN20230508_CLAS           2           #DA808C
# 5       CCN20230508_CLAS           3           #71238C
# 6       CCN20230508_CLAS           4           #DF70FF
# 7       CCN20230508_CLAS           5           #A45FBF
# 8       CCN20230508_CLAS           6           #B1B10C
# 9       CCN20230508_CLAS           7           #FF9900
# 10      CCN20230508_CLAS           8           #D93137
# 11      CCN20230508_CLAS           9           #F641A8
# 12      CCN20230508_CLAS          10           #B1EC30
# 13      CCN20230508_CLAS          13           #A19922
# 14      CCN20230508_CLAS          11           #00E5E5
# 15      CCN20230508_CLAS          12           #50B2AD
# 16      CCN20230508_CLAS          15           #0D5B78
# 17      CCN20230508_CLAS          16           #2D8CB8
# 18      CCN20230508_CLAS          17           #7044AA
# 19      CCN20230508_CLAS          14           #5100FF
# 20      CCN20230508_CLAS          18           #3E9E64
# 21      CCN20230508_CLAS          19           #665C47
# 22      CCN20230508_CLAS          20           #374A45
# 23      CCN20230508_CLAS          21           #53776C
# 24      CCN20230508_CLAS          22           #8D6C62
# 25      CCN20230508_CLAS          23           #697255
# 26      CCN20230508_CLAS          24           #94AF97
#
#    cluster_annotation_term_set_name             parent_term_name  \
# 0                             class                          NaN
# 1                             class                          NaN
# 2                             class                          NaN
# 3                          subclass          Neuronal: GABAergic
# 4                          subclass          Neuronal: GABAergic
# 5                          subclass          Neuronal: GABAergic
# 6                          subclass          Neuronal: GABAergic
# 7                          subclass          Neuronal: GABAergic
# 8                          subclass          Neuronal: GABAergic
# 9                          subclass          Neuronal: GABAergic
# 10                         subclass          Neuronal: GABAergic
# 11                         subclass          Neuronal: GABAergic
# 12                         subclass      Neuronal: Glutamatergic
# 13                         subclass      Neuronal: Glutamatergic
# 14                         subclass      Neuronal: Glutamatergic
# 15                         subclass      Neuronal: Glutamatergic
# 16                         subclass      Neuronal: Glutamatergic
# 17                         subclass      Neuronal: Glutamatergic
# 18                         subclass      Neuronal: Glutamatergic
# 19                         subclass      Neuronal: Glutamatergic
# 20                         subclass      Neuronal: Glutamatergic
# 21                         subclass  Non-neuronal and Non-neural
# 22                         subclass  Non-neuronal and Non-neural
# 23                         subclass  Non-neuronal and Non-neural
# 24                         subclass  Non-neuronal and Non-neural
# 25                         subclass  Non-neuronal and Non-neural
# 26                         subclass  Non-neuronal and Non-neural
#
#        first_child_label first_child_term_set_name
# 0   CS20230508_SUBC_0001                  subclass
# 1   CS20230508_SUBC_0010                  subclass
# 2   CS20230508_SUBC_0019                  subclass
# 3   CS20230508_SUPT_0001                 supertype
# 4   CS20230508_SUPT_0002                 supertype
# 5   CS20230508_SUPT_0008                 supertype
# 6   CS20230508_SUPT_0012                 supertype
# 7   CS20230508_SUPT_0019                 supertype
# 8   CS20230508_SUPT_0035                 supertype
# 9   CS20230508_SUPT_0036                 supertype
# 10  CS20230508_SUPT_0053                 supertype
# 11  CS20230508_SUPT_0066                 supertype
# 12  CS20230508_SUPT_0068                 supertype
# 13  CS20230508_SUPT_0077                 supertype
# 14  CS20230508_SUPT_0079                 supertype
# 15  CS20230508_SUPT_0082                 supertype
# 16  CS20230508_SUPT_0090                 supertype
# 17  CS20230508_SUPT_0092                 supertype
# 18  CS20230508_SUPT_0096                 supertype
# 19  CS20230508_SUPT_0102                 supertype
# 20  CS20230508_SUPT_0105                 supertype
# 21  CS20230508_SUPT_0110                 supertype
# 22  CS20230508_SUPT_0116                 supertype
# 23  CS20230508_SUPT_0120                 supertype
# 24  CS20230508_SUPT_0125                 supertype
# 25  CS20230508_SUPT_0128                 supertype
# 26  CS20230508_SUPT_0132                 supertype

# %%
membership = abc_cache.get_metadata_dataframe(directory='SEAAD-taxonomy', file_name='cluster_to_cluster_annotation_membership')
pivot = membership.groupby(['cluster_alias', 'cluster_annotation_term_set_name'])['cluster_annotation_term_name'].first().unstack()
pivot = pivot[term_sets['name']] # order columns
pivot.fillna('Other', inplace=True)
pivot.sort_values(['class', 'subclass', 'supertype'], inplace=True)
cols = pivot.columns.to_list()
pivot.columns = cols
pivot
# Out:
#                                         class         subclass  \
# cluster_alias
# Chandelier_1              Neuronal: GABAergic       Chandelier
# Chandelier_2              Neuronal: GABAergic       Chandelier
# Lamp5_1                   Neuronal: GABAergic            Lamp5
# Lamp5_2                   Neuronal: GABAergic            Lamp5
# Lamp5_3                   Neuronal: GABAergic            Lamp5
# ...                                       ...              ...
# Oligo_4           Non-neuronal and Non-neural  Oligodendrocyte
# Pericyte_1        Non-neuronal and Non-neural             VLMC
# Pericyte_2-SEAAD  Non-neuronal and Non-neural             VLMC
# SMC-SEAAD         Non-neuronal and Non-neural             VLMC
# VLMC_1            Non-neuronal and Non-neural             VLMC
#
#                          supertype abundancechangecps
# cluster_alias
# Chandelier_1          Chandelier_1          unchanged
# Chandelier_2          Chandelier_2          unchanged
# Lamp5_1                    Lamp5_1          unchanged
# Lamp5_2                    Lamp5_2          unchanged
# Lamp5_3                    Lamp5_3           decrease
# ...                            ...                ...
# Oligo_4                    Oligo_4          unchanged
# Pericyte_1              Pericyte_1          unchanged
# Pericyte_2-SEAAD  Pericyte_2-SEAAD          unchanged
# SMC-SEAAD                SMC-SEAAD          unchanged
# VLMC_1                      VLMC_1          unchanged
#
# [139 rows x 4 columns]

# %%
lookup = {}
for tag in term_sets['name'] :
    #print(tag)
    pred = (term['cluster_annotation_term_set_name'] == tag)
    filtered = term[pred].copy()
    filtered.set_index('name', inplace=True)
    lookup[tag] = filtered

# %% [markdown]
# Helper functions to lookup an term attribut and format a cell in the html table

# %%
def get_value(c, n, v) :
    return lookup[c].loc[n][v]

def format_cell (df,c,add_id=False,add_plus=False,add_minus=False) :

    divs = pd.DataFrame(index=df.index)
    
    pattern = '<div class="circle" style="background-color:%s"></div>'
    divs['circle'] = [pattern % get_value(c,x,'color_hex_triplet') for x in df[c]]
    
    pattern = '<div class="celltext">%s</div>'
    divs['name'] = [pattern % x for x in df[c]]
   
    divs['id'] = ''
    if add_id :
        pattern = '<div id="%s"></div>'
        divs['id'] = [pattern % get_value(c,x,'label') for x in df[c]]
        
    divs['plus'] = ''
    if add_plus :
        pattern = '<div class="celltext"><a href="%s.html#%s">[+]</a></div>'
        divs['plus'] = [pattern % (get_value(c,x,'first_child_term_set_name'),
                                   get_value(c,x,'first_child_label')) for x in df[c]]
        
    divs['minus'] = ''
    if add_minus :
        pattern = '<div class="celltext"><a href="%s.html#%s">[-]</a></div>'
        divs['minus'] = [pattern % (get_value(c,x,'cluster_annotation_term_set_name'),
                                    get_value(c,x,'label')) for x in df[c]]
    
    cols = ['id','circle','name','plus','minus']
    output = divs[cols].apply(lambda row: ''.join(row.values.astype(str)), axis=1)
    return output

# %% [markdown]
# Helper function to create html document

# %%
def create_html(df, ts, file, title):
    
    # apply formatter to each term set
    df_formatted = df.copy()
    
    for tag in term_sets['name'] :
        if tag in df_formatted.columns :
            
            add_id = False
            if tag == ts :
                add_id = True
                
            add_plus = False
            if tag == ts and tag not in ('supertype', 'abundancechangecps') :
                add_plus = True
                
            add_minus = False
            if tag != ts and tag not in ('abundancechangecps') :
                add_minus = True
                
            df_formatted[tag] = format_cell(df,tag,add_id,add_plus,add_minus)
            
            
    output = df_formatted.to_html(index=False, na_rep='',
                        render_links=True,escape=False,
                        classes="mystyle")

    html_string = '''
    <html>
    <head><title>%s</title></head>
    <link rel="stylesheet" type="text/css" href="../../simple_style.css"/>
    <body>
    {table}
    </body>
    </html>.
    ''' % title

    # OUTPUT AN HTML FILE
    with open(file, 'w') as f:
        f.write(html_string.format(table=output))

# %%
# Write the data to the _static directory of the abc_atlas_access so that links work properly in the jupyter-book/sphinx page.
output_directory = os.path.join('../../_static', 'SEAAD-taxonomy', version)
os.makedirs(output_directory, exist_ok=True)

# %%
df_supertype = pivot[['class']].copy()
df_supertype.drop_duplicates(inplace=True)

file = os.path.join(output_directory, 'class.html')
title = 'SEAAD-taxonmy: cell type classes'
create_html(df_supertype, 'class', file, title)
print(len(df_supertype))
# Out:
# 3

# %%
df_supertype = pivot[['class', 'subclass']].copy()
df_supertype.drop_duplicates(inplace=True)

file = os.path.join(output_directory, 'subclass.html')
title = 'SEAAD-taxonmy: cell type subclasses'
create_html(df_supertype, 'subclass', file, title)
print(len(df_supertype))
# Out:
# 24

# %%
df_supertype = pivot[['class', 'subclass', 'supertype', 'abundancechangecps']].copy()
df_supertype.drop_duplicates(inplace=True)

file = os.path.join(output_directory,'supertype.html')
title = 'SEAAD-taxonmy: cell type supertypes'
create_html(df_supertype, 'supertype', file, title)
print(len(df_supertype))
# Out:
# 139
