# %%
import os
import pandas as pd
import numpy as np
import anndata
import time
import matplotlib.pyplot as plt
import json
import requests

# %%
version = '20230830'
download_base = '../../../abc_download_root'

use_local_cache = False
manifest_path = 'releases/%s/manifest.json' % version

if not use_local_cache :
    url = 'https://allen-brain-cell-atlas.s3-us-west-2.amazonaws.com/' + manifest_path
    manifest = json.loads(requests.get(url).text)
else :
    file = os.path.join(download_base,manifest_path)
    with open(file,'rb') as f:
        manifest = json.load(f)
    
metadata = manifest['file_listing']['Allen-CCF-2020']['metadata']

# %% [markdown]
# Read in parcellation annotation term set dataframe

# %%
rpath = metadata['parcellation_term_set']['files']['csv']['relative_path']
file = os.path.join( download_base, rpath)
term_sets = pd.read_csv(file)
term_sets.set_index('label', inplace=True)
term_sets
# Out:
#                                                     description          name  \
# label
# AllenCCF-Ontology-2017-ORGA                               organ         organ
# AllenCCF-Ontology-2017-CATE  mouse brain anatomical catergories      category
# AllenCCF-Ontology-2017-DIVI               mouse brain divisions      division
# AllenCCF-Ontology-2017-STRU              mouse brain structures     structure
# AllenCCF-Ontology-2017-SUBS           mouse brain substructures  substructure
#
#                             parcellation_terminology_label  term_set_order  \
# label
# AllenCCF-Ontology-2017-ORGA         AllenCCF-Ontology-2017               0
# AllenCCF-Ontology-2017-CATE         AllenCCF-Ontology-2017               1
# AllenCCF-Ontology-2017-DIVI         AllenCCF-Ontology-2017               2
# AllenCCF-Ontology-2017-STRU         AllenCCF-Ontology-2017               3
# AllenCCF-Ontology-2017-SUBS         AllenCCF-Ontology-2017               4
#
#                                    parent_term_set_label
# label
# AllenCCF-Ontology-2017-ORGA                          NaN
# AllenCCF-Ontology-2017-CATE  AllenCCF-Ontology-2017-ORGA
# AllenCCF-Ontology-2017-DIVI  AllenCCF-Ontology-2017-CATE
# AllenCCF-Ontology-2017-STRU  AllenCCF-Ontology-2017-DIVI
# AllenCCF-Ontology-2017-SUBS  AllenCCF-Ontology-2017-STRU

# %% [markdown]
# Read in parcellation term membership dataframe

# %%
rpath = metadata['parcellation_to_parcellation_term_membership']['files']['csv']['relative_path']
file = os.path.join( download_base, rpath)
term = pd.read_csv(file)

term.sort_values(['term_set_order','term_order'],inplace=True)

term.head(8)
# Out:
#                     parcellation_label     parcellation_term_label  \
# 0         AllenCCF-Annotation-2020-997  AllenCCF-Ontology-2017-997
# 1          AllenCCF-Annotation-2020-68  AllenCCF-Ontology-2017-997
# 6         AllenCCF-Annotation-2020-667  AllenCCF-Ontology-2017-997
# 11  AllenCCF-Annotation-2020-526157192  AllenCCF-Ontology-2017-997
# 16  AllenCCF-Annotation-2020-526157196  AllenCCF-Ontology-2017-997
# 21  AllenCCF-Annotation-2020-526322264  AllenCCF-Ontology-2017-997
# 26        AllenCCF-Annotation-2020-320  AllenCCF-Ontology-2017-997
# 31        AllenCCF-Annotation-2020-943  AllenCCF-Ontology-2017-997
#
#     parcellation_term_set_label  parcellation_index  voxel_count  volume_mm3  \
# 0   AllenCCF-Ontology-2017-ORGA                 987      3564320    3.564320
# 1   AllenCCF-Ontology-2017-ORGA                  63       256520    0.256520
# 6   AllenCCF-Ontology-2017-ORGA                 657       232608    0.232608
# 11  AllenCCF-Ontology-2017-ORGA                1288       371584    0.371584
# 16  AllenCCF-Ontology-2017-ORGA                1289       112222    0.112222
# 21  AllenCCF-Ontology-2017-ORGA                1290          942    0.000942
# 26  AllenCCF-Ontology-2017-ORGA                 310      1328982    1.328982
# 31  AllenCCF-Ontology-2017-ORGA                 933      3689292    3.689292
#
#    color_hex_triplet  red  green  blue parcellation_term_name  \
# 0            #FFFFFF  255    255   255                  brain
# 1            #FFFFFF  255    255   255                  brain
# 6            #FFFFFF  255    255   255                  brain
# 11           #FFFFFF  255    255   255                  brain
# 16           #FFFFFF  255    255   255                  brain
# 21           #FFFFFF  255    255   255                  brain
# 26           #FFFFFF  255    255   255                  brain
# 31           #FFFFFF  255    255   255                  brain
#
#    parcellation_term_acronym parcellation_term_set_name  term_set_order  \
# 0                      brain                      organ               0
# 1                      brain                      organ               0
# 6                      brain                      organ               0
# 11                     brain                      organ               0
# 16                     brain                      organ               0
# 21                     brain                      organ               0
# 26                     brain                      organ               0
# 31                     brain                      organ               0
#
#     term_order parent_term_label
# 0            0               NaN
# 1            0               NaN
# 6            0               NaN
# 11           0               NaN
# 16           0               NaN
# 21           0               NaN
# 26           0               NaN
# 31           0               NaN

# %% [markdown]
# Find and store first child for each term

# %%
filtered = term[pd.notna(term['parent_term_label'])]
first_child = filtered.groupby('parent_term_label')[['parcellation_term_label','parcellation_term_name','term_order','parcellation_term_set_name']].first()
first_child
# Out:
#                                                 parcellation_term_label  \
# parent_term_label
# ABC-Ontology-2023-AQ-structure        ABC-Ontology-2023-AQ-substructure
# ABC-Ontology-2023-CB-structure        ABC-Ontology-2023-CB-substructure
# ABC-Ontology-2023-CTXsp-structure  ABC-Ontology-2023-CTXsp-substructure
# ABC-Ontology-2023-HPF-structure      ABC-Ontology-2023-HPF-substructure
# ABC-Ontology-2023-HY-structure        ABC-Ontology-2023-HY-substructure
# ...                                                                 ...
# AllenCCF-Ontology-2017-989            ABC-Ontology-2023-FN-substructure
# AllenCCF-Ontology-2017-991                   AllenCCF-Ontology-2017-768
# AllenCCF-Ontology-2017-993                   AllenCCF-Ontology-2017-656
# AllenCCF-Ontology-2017-997             ABC-Ontology-2023-brain-category
# AllenCCF-Ontology-2017-998            ABC-Ontology-2023-FS-substructure
#
#                                               parcellation_term_name  \
# parent_term_label
# ABC-Ontology-2023-AQ-structure                     cerebral aqueduct
# ABC-Ontology-2023-CB-structure                Cerebellum, unassigned
# ABC-Ontology-2023-CTXsp-structure      Cortical subplate, unassigned
# ABC-Ontology-2023-HPF-structure    Hippocampal formation, unassigned
# ABC-Ontology-2023-HY-structure              Hypothalamus, unassigned
# ...                                                              ...
# AllenCCF-Ontology-2017-989                         Fastigial nucleus
# AllenCCF-Ontology-2017-991                          cerebrum related
# AllenCCF-Ontology-2017-993             Secondary motor area, layer 1
# AllenCCF-Ontology-2017-997                         brain, unassigned
# AllenCCF-Ontology-2017-998                        Fundus of striatum
#
#                                    term_order parcellation_term_set_name
# parent_term_label
# ABC-Ontology-2023-AQ-structure            884               substructure
# ABC-Ontology-2023-CB-structure            706               substructure
# ABC-Ontology-2023-CTXsp-structure         368               substructure
# ABC-Ontology-2023-HPF-structure           302               substructure
# ABC-Ontology-2023-HY-structure            474               substructure
# ...                                       ...                        ...
# AllenCCF-Ontology-2017-989                758               substructure
# AllenCCF-Ontology-2017-991                358                  structure
# AllenCCF-Ontology-2017-993                 11               substructure
# AllenCCF-Ontology-2017-997                  0                   category
# AllenCCF-Ontology-2017-998                382               substructure
#
# [391 rows x 4 columns]

# %%
rpath = metadata['parcellation_term']['files']['csv']['relative_path']
file = os.path.join( download_base, rpath)
info = pd.read_csv(file)
info.set_index('label',inplace=True)
info.head(5)
# Out:
#                            acronym                           name  \
# label
# AllenCCF-Ontology-2017-997   brain                          brain
# AllenCCF-Ontology-2017-8      grey  Basic cell groups and regions
# AllenCCF-Ontology-2017-567      CH                       Cerebrum
# AllenCCF-Ontology-2017-688     CTX                Cerebral cortex
# AllenCCF-Ontology-2017-695   CTXpl                 Cortical plate
#
#                            color_hex_triplet  graph_order identifier  red  \
# label
# AllenCCF-Ontology-2017-997           #FFFFFF          0.0    MBA:997  255
# AllenCCF-Ontology-2017-8             #BFDAE3          1.0      MBA:8  191
# AllenCCF-Ontology-2017-567           #B0F0FF          2.0    MBA:567  176
# AllenCCF-Ontology-2017-688           #B0FFB8          3.0    MBA:688  176
# AllenCCF-Ontology-2017-695           #70FF70          4.0    MBA:695  112
#
#                             green  blue parent_identifier
# label
# AllenCCF-Ontology-2017-997    255   255               NaN
# AllenCCF-Ontology-2017-8      218   227           MBA:997
# AllenCCF-Ontology-2017-567    240   255             MBA:8
# AllenCCF-Ontology-2017-688    255   184           MBA:567
# AllenCCF-Ontology-2017-695    255   112           MBA:688

# %%
term.set_index('parcellation_term_label',inplace=True)
term.loc[first_child.index,'first_child_label'] = first_child['parcellation_term_label']
term.loc[first_child.index,'first_child_term_set_name'] = first_child['parcellation_term_set_name']
term = term.join(info['identifier'])
term.reset_index(inplace=True)

# %%
term[pd.notna(term['first_child_label'])].tail(5)
# Out:
#          parcellation_term_label            parcellation_label  \
# 3435  AllenCCF-Ontology-2017-997  AllenCCF-Annotation-2020-140
# 3436  AllenCCF-Ontology-2017-997  AllenCCF-Annotation-2020-145
# 3437  AllenCCF-Ontology-2017-997  AllenCCF-Annotation-2020-153
# 3438  AllenCCF-Ontology-2017-997  AllenCCF-Annotation-2020-164
# 3439  AllenCCF-Ontology-2017-998  AllenCCF-Annotation-2020-998
#
#       parcellation_term_set_label  parcellation_index  voxel_count  \
# 3435  AllenCCF-Ontology-2017-ORGA                 135       405256
# 3436  AllenCCF-Ontology-2017-ORGA                 140       499566
# 3437  AllenCCF-Ontology-2017-ORGA                 148       461680
# 3438  AllenCCF-Ontology-2017-ORGA                 159          432
# 3439  AllenCCF-Ontology-2017-STRU                 988       428468
#
#       volume_mm3 color_hex_triplet  red  green  blue parcellation_term_name  \
# 3435    0.405256           #FFFFFF  255    255   255                  brain
# 3436    0.499566           #FFFFFF  255    255   255                  brain
# 3437    0.461680           #FFFFFF  255    255   255                  brain
# 3438    0.000432           #FFFFFF  255    255   255                  brain
# 3439    0.428468           #80CDF8  128    205   248     Fundus of striatum
#
#      parcellation_term_acronym parcellation_term_set_name  term_set_order  \
# 3435                     brain                      organ               0
# 3436                     brain                      organ               0
# 3437                     brain                      organ               0
# 3438                     brain                      organ               0
# 3439                        FS                  structure               3
#
#       term_order           parent_term_label  \
# 3435           0                         NaN
# 3436           0                         NaN
# 3437           0                         NaN
# 3438           0                         NaN
# 3439          83  AllenCCF-Ontology-2017-477
#
#                       first_child_label first_child_term_set_name identifier
# 3435   ABC-Ontology-2023-brain-category                  category    MBA:997
# 3436   ABC-Ontology-2023-brain-category                  category    MBA:997
# 3437   ABC-Ontology-2023-brain-category                  category    MBA:997
# 3438   ABC-Ontology-2023-brain-category                  category    MBA:997
# 3439  ABC-Ontology-2023-FS-substructure              substructure    MBA:998

# %% [markdown]
# Create pivot of term order

# %%
df = term.groupby(['parcellation_index','parcellation_term_set_name'])['term_order'].first().unstack()
df = df[term_sets['name']] # order columns
df_sorted = df.sort_values(['organ','category','division','structure','substructure'])
df_sorted.columns = list(df_sorted.columns)
df_sorted
# Out:
#                     organ  category  division  structure  substructure
# parcellation_index
# 987                     0         0         0          0             0
# 63                      0         1         1          1             1
# 657                     0         1         1          1             2
# 1288                    0         1         1          1             3
# 1289                    0         1         1          1             4
# ...                   ...       ...       ...        ...           ...
# 135                     0         3        22        366           884
# 140                     0         3        23        367           885
# 148                     0         3        23        368           886
# 159                     0         3        24        369           887
# 0                       1         4        25        370           888
#
# [688 rows x 5 columns]

# %%
term.groupby(['parcellation_index','parcellation_term_set_name'])['term_order'].first().unstack()
# Out:
# parcellation_term_set_name  category  division  organ  structure  substructure
# parcellation_index
# 0                                  4        25      1        370           888
# 1                                  1         8      0        179           518
# 2                                  1         1      0          7            40
# 5                                  2        17      0        350           820
# 6                                  1        10      0        239           615
# ...                              ...       ...    ...        ...           ...
# 1323                               1         9      0        233           603
# 1324                               1         9      0        233           604
# 1325                               1         9      0        233           605
# 1326                               1         9      0        233           606
# 1327                               1         9      0        210           575
#
# [688 rows x 5 columns]

# %% [markdown]
# Create a lookup by name dataframes for each term set

# %%
lookup = {}
for tag in term_sets['name'] :
    #print(tag)
    pred = (term['parcellation_term_set_name'] == tag)
    filtered = term[pred].copy()
    filtered.drop(['parcellation_label','parcellation_index','voxel_count','volume_mm3'], inplace=True, axis=1)
    filtered.drop_duplicates(inplace=True)
    filtered.set_index('term_order', inplace=True)
    lookup[tag] = filtered

# %% [markdown]
# Helper functions to lookup an term attribut and format a cell in the html table

# %%
def get_value( c, n, v ) :
    return lookup[c].loc[n][v]

def format_cell (df,c,add_id=False,add_plus=False,add_minus=False,add_name=False,add_atlas=False) :

    divs = pd.DataFrame(index=df.index)
    
    pattern = '<div class="circle" style="background-color:%s"></div>'
    divs['circle'] = [ pattern % get_value(c,x,'color_hex_triplet') for x in df[c] ]
    
    pattern = '<div class="celltext", title="%s"><b>%s</b></div>'
    divs['name'] = [ pattern % (get_value(c,x,'parcellation_term_name'),
                                get_value(c,x,'parcellation_term_acronym')) for x in df[c] ]
    
    divs['desc'] = ''
    if add_name :
        pattern = '<div class="celltext">%s</div>'
        divs['desc'] = [ pattern % get_value(c,x,'parcellation_term_name') for x in df[c] ]
   
    divs['id'] = ''
    if add_id :
        pattern = '<div id="%s"></div>'
        divs['id'] = [ pattern % get_value(c,x,'parcellation_term_label') for x in df[c] ]
        
    divs['plus'] = ''
    if add_plus :
        pattern = '<div class="celltext"><a href="%s.html#%s">[+]</a></div>'
        divs['plus'] = [ pattern % (get_value(c,x,'first_child_term_set_name'),
                                    get_value(c,x,'first_child_label')) for x in df[c] ]
        
    divs['minus'] = ''
    if add_minus :
        pattern = '<div class="celltext"><a href="%s.html#%s">[-]</a></div>'
        divs['minus'] = [ pattern % (get_value(c,x,'parcellation_term_set_name'),
                                    get_value(c,x,'parcellation_term_label')) for x in df[c] ]
        
    divs['atlas'] = ''
    if add_atlas :
        pattern = '<div class="celltext"><a href="https://atlas.brain-map.org/atlas?atlas=602630314&structure=%s">[A]</a></div>'
        sid = pd.Series([get_value(c,x,'identifier') for x in df[c]])
        sid[pd.isna(sid)] = 'MBA:0'
        sid = [x.split(':')[1] for x in sid]
        divs['atlas'] = [pattern % x for x in sid ]
    
    cols = ['id','circle','name','desc','plus','minus','atlas']
    output = divs[cols].apply(lambda row: ''.join(row.values.astype(str)), axis=1)
    return output

# %% [markdown]
# Helper function to create html document

# %%
def create_html (df,ts,file,title) :
    
    # apply formatter to each term set
    df_formatted = df.copy()
    
    for tag in term_sets['name'] :
        if tag in df_formatted.columns :
            
            #print(tag)
            
            add_id = False
            add_name = False
            add_atlas = False
            if tag == ts :
                add_id = True
                add_name = True
                add_atlas = True
                
            add_plus = False
            if tag == ts and tag not in ['substructure'] :
                add_plus = True
                
            add_minus = False
            if tag != ts and tag not in ['organ'] :
                add_minus = True
                
            df_formatted[tag] = format_cell(df,tag,add_id,add_plus,add_minus,add_name,add_atlas)
            
            
    output = df_formatted.to_html(index=False, na_rep='',
                        render_links=True,escape=False,
                        classes="mystyle")

    html_string = '''
    <html>
    <head><title>%s</title></head>
    <link rel="stylesheet" type="text/css" href="../simple_style.css"/>
    <body>
    {table}
    </body>
    </html>.
    ''' % title

    # OUTPUT AN HTML FILE
    with open(file, 'w') as f:
        f.write(html_string.format(table=output))

# %%
output_directory = 'Allen-CCF-2020'
os.makedirs( output_directory, exist_ok=True)

# %%
subset = df_sorted[['division']].copy()
subset.drop_duplicates(inplace=True)

file = os.path.join(output_directory,'division.html')
title = 'Allen-CCF-2020: anatomical divisions'
create_html(subset, 'division',file, title)
print(len(subset))
# Out:
# 26

# %%
subset = df_sorted[['division','structure','substructure']].copy()
subset.drop_duplicates(inplace=True)

file = os.path.join(output_directory,'substructure.html')
title = 'Allen-CCF-2020: anatomical substructures'
create_html(subset, 'substructure',file, title)
print(len(subset))
# Out:
# 681

# %%
subset = df_sorted[['division','structure']].copy()
subset.drop_duplicates(inplace=True)

file = os.path.join(output_directory,'structure.html')
title = 'Allen-CCF-2020: anatomical structure'
create_html(subset, 'structure',file, title)
print(len(subset))
# Out:
# 358
